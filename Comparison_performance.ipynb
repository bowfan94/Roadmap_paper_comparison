# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# Out:
# D:\Software\Anaconda\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# D:\Software\Anaconda\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
# D:\Software\Anaconda\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
performance_all = pd.read_csv('./performance.csv',index_col=0)
performance_all
# Out:
#                                                     auroc_ori  auroc_1d  \
# hibachi-res_BernoulliNB_DecisionTreeClassifier-...   0.543981  0.522393
# hibachi-res_BernoulliNB_DecisionTreeClassifier-...   0.594141  0.572879
# hibachi-res_BernoulliNB_DecisionTreeClassifier-...   0.581924  0.500000
# hibachi-res_BernoulliNB_DecisionTreeClassifier-...   0.508051  0.500000
# hibachi-res_BernoulliNB_DecisionTreeClassifier-...   0.565650  0.544550
# ...                                                       ...       ...
# hibachi-res_XGBClassifier_RandomForestClassifie...   0.484424  0.555802
# hibachi-res_XGBClassifier_RandomForestClassifie...   0.508772  0.500000
# hibachi-res_XGBClassifier_RandomForestClassifie...   0.474887  0.568622
# hibachi-res_XGBClassifier_RandomForestClassifie...   0.487856  0.500000
# hibachi-res_XGBClassifier_RandomForestClassifie...   0.504908  0.512220
#
#                                                     auroc_2d  auroc_12d  \
# ...

# %%
x = [0, 1]
plt.figure(figsize=(10, 16))
red_count = 0
green_count = 0
for i in range(len(performance_all)):
    c = 'r' if performance_all.iloc[i, 3] >= performance_all.iloc[i, 0] else 'g'
    plt.plot(x, performance_all.iloc[i, [0, 3]], color=c)

plt.title('PRS-MRS', fontsize=30)
plt.ylabel('AUROC', fontsize=20)
plt.xticks([0,1],['PRS', 'MRS'],fontsize=20)
plt.tight_layout()
plt.show()

# %%
x = [0, 1]
plt.figure(figsize=(10, 16))
red_count = 0
green_count = 0
for i in range(len(performance_all)):
    c = 'r' if performance_all.iloc[i, 3] >= performance_all.iloc[i, 4] else 'g'
    plt.plot(x, performance_all.iloc[i, [4, 3]], color=c)

plt.title('NN-MRS', fontsize=30)
plt.ylabel('AUROC', fontsize=20)
plt.xticks([0,1],['NN', 'MRS'],fontsize=20)
plt.tight_layout()
plt.show()

# %%
x = [0, 1]
plt.figure(figsize=(10, 16))
red_count = 0
green_count = 0
for i in range(len(performance_all)):
    c = 'r' if performance_all.iloc[i, 0] >= performance_all.iloc[i, 6] else 'g'
    plt.plot(x, performance_all.iloc[i, [6, 0]], color=c)

plt.title('NN-PRS', fontsize=30)
plt.ylabel('AUROC', fontsize=20)
plt.xticks([0,1],['NN', 'PRS'],fontsize=20)
plt.tight_layout()
plt.show()

# %%
x = [0, 1]
plt.figure(figsize=(10, 16))
red_count = 0
green_count = 0
for i in range(len(performance_all)):
    c = 'r' if performance_all.iloc[i, 3] >= performance_all.iloc[i, 6] else 'g'
    plt.plot(x, performance_all.iloc[i, [6, 3]], color=c)

plt.title('NN-MRS', fontsize=30)
plt.ylabel('AUROC', fontsize=20)
plt.xticks([0,1],['NN', 'MRS'], fontsize=20)
plt.tight_layout()
plt.show()
